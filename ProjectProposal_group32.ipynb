# %% [markdown]
# # COGS 108 - Final Project Proposal

# %% [markdown]
# # Names
#
#  - Pranaav Deshpande
#  - Kin Lo
#  - Bryce Lozinski
#  - Jack Steussie

# %% [markdown]
# # Group Members IDs
#
#  - A15733665
#  - A13613509
#  - A13518372
#  - A15457432

# %% [markdown]
# # Research Question

# %% [markdown]
# Do electric vehicles help improve air quality?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Air pollution is a major respiratory health risk; it has been linked deaths in the U.S as well as decreasing life expectancy. The biggest contributor to air pollution are from automobiles, which releases high concentrations of greenhouse gases, such as $NO_{x}$, $PM_{2.5}$, $CO$, and $SO_{2}$ [1]. These greenhouse gases (GHG) are detrimental to the environment as well as human health. Most vehicles release GHG when they are being driven. However, electric vehicles produce fewer emissions as it does not emit exhaust from the tailpipe [2]. Instead, most electric vehicles' emissions come from electric power plants. This results in fewer GHG emissions compared to an internal combustion vehicle,  decreasing photochemical smog and improving air quality.
#
# The number of electric vehicles have exponentially increased from 2011 - 2018 [3][4], while the average air pollutants concentrations in the U.S has steadily declined and air quality has been improving [5]. Studies have found that adopting electric vehicles has a positive impact on air quality by reducing carbon and other pollutants emissions [6]. Transportation accounts for over 20% of greenhouse gas emissions, so by switching to an electric vehicle, we can reduce our GHG emissions and improve air quality.
#
# References:
# 1. https://www.epa.gov/greenvehicles/greenhouse-gas-emissions-typical-passenger-vehicle
# 2. https://www.energy.gov/eere/electricvehicles/reducing-pollution-electric-vehicles
# 3. https://www.eei.org/issuesandpolicy/electrictransportation/Documents/EV_%20Sales%20Facts%20and%20Figures.pdf
# 4. https://afdc.energy.gov/data/10567
# 5. https://gispub.epa.gov/air/trendsreport/2018/#unhealthy_aq_days
# 6. https://www.sciencedaily.com/releases/2019/04/190412122912.htm

# %% [markdown]
# # Hypothesis

# %% [markdown]
# The introduction of electric cars have significantly improved air quality because electric cars are reducing the amount of emissions and particulate matter that are being produced

# %% [markdown]
# # Data

# %% [markdown]
# The ideal dataset we want are the trends of different pollutants ($NO_{x}$, $PM_{2.5}$, $CO$, and $SO_{2}$) over ten years. The different pollutants data are collected from U.S EPA Air Quality System. We want to focus on the increase in sales of electric vehicles, which can be collected from Argonne National Laboratory. There is no longer a free data source that releases the sales of electric vehicles by make and model on a monthly basis, instead it is released quarterly. Edison Electric Institute also has the number of electric vehicles on the road in the U.S. These data are in csv format. We would like to see the trends of each pollutant as well as air quality compared to the rise in sales of electric vehicles.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Data involving air pollution trends was provided in the U.S Environmental Protection Agency and were collected by the  EPA, state, local, and tribal air pollution agencies. These data are intended for use in the regulartory, academic, and health research institutions only. All data from U.S EPA must be cited.
#
# All vehicles sales are released in different industry sales' reports, Electric Drive Transportation Association, InsideEVs, and HybridCars and are compiled by Argonne National Laboratory's Center for Transportation Research. Electric Edison Institute also uses InsideEVs and HybridCars. Sales are also reported to the U.S. Department of Energy’s Vehicle Technologies Office each month. Companies' sales' report are public and accessible through their website.
#
# Data from air pollution trends and electric vehicle sales were collected in the United States. These data do not include any personal information.

# %% [markdown]
# # Team Expectations

# %% [markdown]
#  - We will communicate through Facebook messenger and Zoom to give each other updates once a week.
#  - Delegated tasks should be completed by the pre-determined deadlines outlined in the proposal.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 04/21  |  2 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 04/22  |  6 PM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 04/24  | 8 PM  | Edit, finalize, and submit proposal  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 04/28  | 6 PM  | Search for datasets
# | 05/08  | 6 PM  | Import & Wrangle Data (Jack); EDA (Bryce) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 05/22  | 12 PM  | Finalize wrangling/EDA; Begin Analysis (Pranaav; Kin) | Discuss/edit Analysis; Complete project check-in |
# | 06/05  | 12 PM  | Complete analysis; Draft results/conclusion/discussion (Kin)| Discuss/edit full project |
# | 06/10  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
